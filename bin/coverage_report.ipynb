# %%
from wand.image import Image
from IPython.display import display
from glob import glob
import os, sys

os.chdir('/home/john.palmer/work/norovirus/results-mar-8-8/qc/coverage/plots')
files = sorted(glob("*pdf"))

# %%
for fig in files:
	print(os.path.basename(fig).split("_")[0])
	#print(fig)
	img = Image(filename=fig)
	display(img)
# Out:
# 1-121
# <wand.image.Image: ca1188a 'PDF' (576x504)>
# 1-135
# <wand.image.Image: 6e4b1b6 'PDF' (576x504)>
# 1-147
# <wand.image.Image: 4b97e84 'PDF' (576x504)>
# 1-209
# <wand.image.Image: 70923ee 'PDF' (576x504)>
# 1-210
# <wand.image.Image: f0c2823 'PDF' (576x504)>
# 1-258
# <wand.image.Image: d612eea 'PDF' (576x504)>
# 1-288
# <wand.image.Image: 968d186 'PDF' (576x504)>
# 1-373
# <wand.image.Image: 103a354 'PDF' (576x504)>
# 1-494
# <wand.image.Image: 8de0dbc 'PDF' (576x504)>
# 5-121
# <wand.image.Image: 465fbdf 'PDF' (576x504)>
# 5-135
# <wand.image.Image: 0df4b7e 'PDF' (576x504)>
# 5-147
# <wand.image.Image: 5daca9e 'PDF' (576x504)>
# 5-209
# <wand.image.Image: 0e79d90 'PDF' (576x504)>
# 5-210
# <wand.image.Image: 4686f34 'PDF' (576x504)>
# 5-238
# <wand.image.Image: 5748c24 'PDF' (576x504)>
# 5-258
# <wand.image.Image: 89ff6cc 'PDF' (576x504)>
# 5-288
# <wand.image.Image: 09a4f8b 'PDF' (576x504)>
# 5-373
# <wand.image.Image: ba46ff7 'PDF' (576x504)>
# 5-494
# <wand.image.Image: 06bdedf 'PDF' (576x504)>
