# %%
from wand.image import Image
from IPython.display import display
from glob import glob
import os, sys

os.chdir('/home/john.palmer/work/norovirus/results-may-1-comp/qc/coverage/plots')
files = sorted(glob("*pdf"))

# %%
for fig in files:
	print(os.path.basename(fig).split("_")[0])
	#print(fig)
	img = Image(filename=fig)
	display(img)
# Out:
# 271695050
# <wand.image.Image: 6fd5686 'PDF' (576x504)>
# 271697525
# <wand.image.Image: f7701e2 'PDF' (576x504)>
# 2891705050
# <wand.image.Image: f2e83ca 'PDF' (576x504)>
# 975575050
# <wand.image.Image: 6a5ca41 'PDF' (576x504)>
# FV17557
# <wand.image.Image: 03900ff 'PDF' (576x504)>
# FV18395
# <wand.image.Image: 95e8355 'PDF' (576x504)>
# FV1897
# <wand.image.Image: 5d117cf 'PDF' (576x504)>
# FV19199
# <wand.image.Image: f49eb1d 'PDF' (576x504)>
# FV19791
# <wand.image.Image: 275bc02 'PDF' (576x504)>
# FV19890
# <wand.image.Image: 058ab60 'PDF' (576x504)>
# FV20009
# <wand.image.Image: c92be06 'PDF' (576x504)>
# FV20126
# <wand.image.Image: 1455df2 'PDF' (576x504)>
# FV20214
# <wand.image.Image: f8d66a4 'PDF' (576x504)>
# FV2072
# <wand.image.Image: 6c43c5b 'PDF' (576x504)>
# FV22115
# <wand.image.Image: dcd8f5f 'PDF' (576x504)>
# FV22128
# <wand.image.Image: e10701f 'PDF' (576x504)>
# FV22141
# <wand.image.Image: 4bac645 'PDF' (576x504)>
# FV22178
# ...
